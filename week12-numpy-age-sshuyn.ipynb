# %% [markdown]
# # 사용 파이썬 점검

# %%
import sys
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'

# %%
import site
site.getsitepackages()
# Out:
# ['c:\\Users\\102\\anaconda3', 'c:\\Users\\102\\anaconda3\\lib\\site-packages']

# %% [markdown]
# # numpy hist()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=[1,1,2,3,4,5,7,8,9,10]
plt.hist(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=[10,1,2,3,4,5,7,8,9,1]
plt.hist(data, bins=3, rwidth=.9)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=[10,1,2,3,4,5,7,8,9,1]
arr, arrbin, c = plt.hist(data, bins=3, rwidth=.9)
print(arr)
print(arrbin)
plt.show()
# Out:
# [4. 2. 4.]
# [ 1.  4.  7. 10.]

# %%
np.random.choice(6,10)
# Out:
# array([5, 0, 3, 3, 2, 3, 0, 2, 0, 3])

# %%
import matplotlib.pyplot as plt
import numpy as np

dice=np.random.choice(6,10)

plt.hist(dice,bins=6)
print(dice)
plt.show()
# Out:
# [0 4 0 1 2 4 2 4 0 5]

# %%
import matplotlib.pyplot as plt
import numpy as np

dice=np.random.choice(6,10)

plt.hist(dice,bins=np.arange(-.5,6.5))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

dice=np.random.choice(6,1000000, p = [0.1,0.2,0.3,0.2,0.1,0.1])

plt.hist(dice,bins=np.arange(-.5,6.5))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.randint(10,100,200)
y=np.random.randint(10,100,200)
size=np.random.randint(10,100,200)

plt.scatter(x,y,s=size,c=x,cmap='jet',alpha=0.7)
plt.colorbar()
plt.show()

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
import numpy as np

a=np.array([1,2,3,4])
print(a[1],a[-1])
print(a[1:])
# Out:
# 2 4
# [2 3 4]

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(-np.pi, np.pi, np.pi/100)

plt.plot(a,np.sin(a))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(-np.pi, np.pi, np.pi/100)

plt.plot(a,np.sin(a))
plt.plot(a,np.cos(a))
plt.plot(a+np.pi/2,np.sin(a))
plt.show()

# %%
import numpy as np
a=np.arange(-5,5)
print(a)
print(a<0)
print(a[a<0])
# Out:
# [-5 -4 -3 -2 -1  0  1  2  3  4]
# [ True  True  True  True  True False False False False False]
# [-5 -4 -3 -2 -1]

# %%
import numpy as np

a=np.arange(-5,5)
print(a)

mask1=(abs(a)>3)
print(mask1)
print(a[mask1])

mask2=((abs(a)%2==0))
print(mask2)
print(a[mask2])

print(a[mask1+mask2])
print(a[mask1*mask2])
# Out:
# [-5 -4 -3 -2 -1  0  1  2  3  4]
# [ True  True False False False False False False False  True]
# [-5 -4  4]
# [False  True False  True False  True False  True False  True]
# [-4 -2  0  2  4]
# [-5 -4 -2  0  2  4]
# [-4  4]

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.randint(-100,100,1000)
y=np.random.randint(-100,100,1000)

mask1=(abs(x)>50)
mask2=(abs(y)>50)
x=x[mask1+mask2]
y=y[mask1+mask2]

plt.scatter(x,y,c=x,cmap='jet',alpha=0.7)
plt.colorbar()
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
# f=open('age.csv', encoding='cp949')
f=open('age(1).csv', encoding='cp949')
data=csv.reader(f)

header = next(data)

name=input('인구구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    if name in data:
        if name in row[0]:
            home=np.array(row[3:], dtype=int)
f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home)
plt.title(name+'지역의 인구구조')
plt.grid(True)
plt.xlabel('나이')
plt.ylabel('인구수')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9976\3277264878.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 # f=open('age.csv', encoding='cp949')
# ----> 5 f=open('age(1).csv', encoding='cp949')
#       6 data=csv.reader(f)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'age(1).csv'

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f=open('age.csv',encoding='cp949')
data = csv.reader(f)

header = next(data)

name=input('인구구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    if name in row[0]:
        home=np.array(row[3:], dtype=int)
    if '화촌면' in row[0]:
        homeB=np.array(row[3:], dtype=int)
f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home, label=name)
plt.plot(homeB, label='화촌면')
plt.title(name+'지역의 인구구조')
plt.grid(True)
plt.xlabel('나이')
plt.ylabel('인구수')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9976\2846436522.py in <module>
#       6 data = csv.reader(f)
#       7
# ----> 8 header = next(data)
#       9
#      10 name=input('인구구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xed in position 1: illegal multibyte sequence

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f=open('age.csv', encoding='cp')
